# %%
from IPython.display import display, SVG
import pydot
from PIL import Image as img
import matplotlib.pyplot as plt

# %%
with open('/home/alexm/simulation_logs/diagram_log.txt') as file:
    string = file.read()
svg = pydot.graph_from_dot_data(string)[0].create_svg()

# %%
display(SVG(svg))
